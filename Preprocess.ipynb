# %%
import pickle as pk
import numpy as np
import pandas as pd
from sklearn import preprocessing

datasets = ['2dplanes', 'abalone','add10', 'airfoil_self_noise','ana','auto_mpg','bank32','bank8','bas','bike_sharing','boston',
            'ca','cal','casp','combined_cycle_power_plant','communities_and_crime','concrete_compressive_strength','cpu_small',
            'dee','diamond','ele1','ele2','electrical_grid_stability_simulated_data',
            'energy_efficiency_cooling_load','energy_efficiency_heating_load','fat',
            'fried','house16','house8','kine32',
            'kine8','laser','liver_disorders','machinecpu','metro_interstate traffic_volume','mor','mv',
            'parkinson_telemonitoring_motor_updrs','parkinson_telemonitoring_total_updrs','pla','pole','puma32','puma8','qua',
            'real_state_valuation','sto',
            'student_performance_math','student_performance_portuguese','superconductivity_data','tre','wan','wine_quality_red',
            'wine_quality_white','wiz','yh'
           ]

# %%
for dataset in datasets: 
    print(dataset)
    #read data 
    X = pd.read_csv(f'data/{dataset}/X.csv')
    x = X.values #returns a numpy array

    #normalize
    min_max_scaler = preprocessing.MinMaxScaler()
    x_scaled = min_max_scaler.fit_transform(x)

    #save data 
    X_norm = pd.DataFrame(data=x_scaled, columns=X.columns)
    X_norm.to_csv(f'data/{dataset}/X_norm.csv', index=False)
# Out:
# 2dplanes
# abalone
# add10
# airfoil_self_noise
# ana
# auto_mpg
# bank32
# bank8
# bas
# bike_sharing
# boston
# ca
# cal
# casp
# combined_cycle_power_plant
# communities_and_crime
# concrete_compressive_strength
# cpu_small
# dee
# diamond
# ele1
# ele2
# electrical_grid_stability_simulated_data
# energy_efficiency_cooling_load
# energy_efficiency_heating_load
# fat
# fried
# house16
# house8
# kine32
# kine8
# laser
# liver_disorders
# machinecpu
# metro_interstate traffic_volume
# mor
# mv
# parkinson_telemonitoring_motor_updrs
# parkinson_telemonitoring_total_updrs
# pla
# pole
# puma32
# puma8
# qua
# real_state_valuation
# sto
# student_performance_math
# student_performance_portuguese
# superconductivity_data
# tre
# wan
# wine_quality_red
# wine_quality_white
# wiz
# yh

# %%
for dataset in datasets: 
    print(dataset)
    #read data 
    X = pd.read_csv(f'data/{dataset}/X.csv')
    print(X.shape)
# Out:
# 2dplanes
# (40768, 10)
# abalone
# (4177, 10)
# add10
# (9792, 10)
# airfoil_self_noise
# (1503, 5)
# ana
# (4052, 7)
# auto_mpg
# (392, 25)
# bank32
# (8192, 32)
# bank8
# (8192, 8)
# bas
# (337, 16)
# bike_sharing
# (731, 13)
# boston
# (506, 13)
# ca
# (8192, 21)
# cal
# (20640, 8)
# casp
# (45730, 9)
# combined_cycle_power_plant
# (9568, 4)
# communities_and_crime
# (319, 122)
# concrete_compressive_strength
# (1030, 8)
# cpu_small
# (8192, 12)
# dee
# (365, 6)
# diamond
# (308, 18)
# ele1
# (495, 2)
# ele2
# (1056, 4)
# electrical_grid_stability_simulated_data
# (10000, 12)
# energy_efficiency_cooling_load
# (768, 8)
# energy_efficiency_heating_load
# (768, 8)
# fat
# (252, 14)
# fried
# (1200, 5)
# house16
# (22784, 16)
# house8
# (22784, 8)
# kine32
# (8192, 32)
# kine8
# (8192, 8)
# laser
# (993, 4)
# liver_disorders
# (345, 5)
# machinecpu
# (209, 6)
# metro_interstate traffic_volume
# (48204, 54)
# mor
# (1049, 15)
# mv
# (40768, 10)
# parkinson_telemonitoring_motor_updrs
# (5875, 18)
# parkinson_telemonitoring_total_updrs
# (5875, 18)
# pla
# (1650, 2)
# pole
# (14998, 26)
# puma32
# (8192, 32)
# puma8
# (8192, 8)
# qua
# (2178, 3)
# real_state_valuation
# (414, 6)
# sto
# (950, 9)
# student_performance_math
# (395, 43)
# student_performance_portuguese
# (649, 43)
# superconductivity_data
# (21263, 81)
# tre
# (1049, 15)
# wan
# (1609, 9)
# wine_quality_red
# (1599, 11)
# wine_quality_white
# (4898, 11)
# wiz
# (1461, 9)
# yh
# (308, 6)
